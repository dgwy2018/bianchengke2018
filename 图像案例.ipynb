# %% [markdown]
# /Users/liangqun/Documents/2018ttup/IMG_8591.jpg
#
# /Users/liangqun/Documents/2018ttup/IMG_8591.jpg

# %%
import ImageEnhance
enhancer = ImageEnhance.Sharpness(img)
img = Image.open('/Users/liangqun/Documents/2018ttup/IMG_8591.jpg')
for i in range(8):
    factor = i / 4.0
    enhancer.enhance(factor).show("Sharpness %f" % factor)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-ad8e5876c69b> in <module>()
# ----> 1 import ImageEnhance
#       2 enhancer = ImageEnhance.Sharpness(img)
#       3 img = Image.open('/Users/liangqun/Documents/2018ttup/IMG_8591.jpg')
#       4 for i in range(8):
#       5     factor = i / 4.0
#
# ModuleNotFoundError: No module named 'ImageEnhance'

# %%
from PIL import Image
import matplotlib.pyplot as plt
img=Image.open('e:/333.jpg')
plt.figure("dog")
plt.imshow(img)
plt.show()

# %%
from PIL import Image
import numpy as np
img = Image.open('e:/333.jpg')
a = np.array(Image.open("e:/333.jpg"))
print(a.shape,a.dtype)
# Out:
# (300, 533, 3) uint8

# %%
from PIL import Image
import numpy as np
img = Image.open('e:/333.jpg')
a = np.array(Image.open("e:/333.jpg"))
print(a.shape,a.dtype)
b = [255,255,255] -a
# Out:
# (300, 533, 3) uint8

# %%
from PIL import Image
import numpy as np
a = np.array(Image.open("e:/333.jpg").convert('L'))
b = 155 - a
im = Image.fromarray(b.astype("uint8"))
im.save("e:/333ccccc.jpg")
im.show()

# %%
from PIL import Image
import numpy as np
img = Image.open('e:/yyy.jpg')
a = np.array(Image.open("e:/yyy.jpg"))
b = [255,255,155] -a
im = Image.fromarray(b.astype("uint8"))
im.save("e:/333ccc.jpg")
im.show()

# %%
from PIL import Image
import numpy as np
 
a = np.asarray(Image.open('e:/yyy.jpg').convert('L')).astype('float')
 
depth = 10.                     # (0-100)
grad = np.gradient(a)            #取图像灰度的梯度值
grad_x, grad_y = grad              #分别取横纵图像梯度值
grad_x = grad_x*depth/100.
grad_y = grad_y*depth/100.
A = np.sqrt(grad_x**2 + grad_y**2 + 1.)
uni_x = grad_x/A
uni_y = grad_y/A
uni_z = 1./A
 
vec_el = np.pi/2.2                  # 光源的俯视角度，弧度值
vec_az = np.pi/4.                   # 光源的方位角度，弧度值
dx = np.cos(vec_el)*np.cos(vec_az)  #光源对x 轴的影响
dy = np.cos(vec_el)*np.sin(vec_az)  #光源对y 轴的影响
dz = np.sin(vec_el)             #光源对z 轴的影响
 
b = 255*(dx*uni_x + dy*uni_y + dz*uni_z)    #光源归一化
b = b.clip(0,255)
 
im = Image.fromarray(b.astype('uint8')) #重构图像
im.save('e:/xxxshouhui.jpg')
im.show()

# %%
#图片变素描
from PIL import Image, ImageFilter, ImageOps
img = Image.open('e:/111.jpg')
def dodge(a, b, alpha):
    return min(int(a*255/(256-b*alpha)), 255)
def draw(img, blur=25, alpha=1.0):
    img1 = img.convert('L')        #图片转换成灰色
    img2 = img1.copy()
    img2 = ImageOps.invert(img2)
    for i in range(blur):          #模糊度
        img2 = img2.filter(ImageFilter.BLUR)
    width, height = img1.size
    for x in range(width):
        for y in range(height):
            a = img1.getpixel((x, y))
            b = img2.getpixel((x, y))
            img1.putpixel((x, y), dodge(a, b, alpha))
    img1.show()
    #img1.save(''e:/yyy111.jpg'')
draw(img)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-16-ad940100ea02> in <module>()
#       1 from PIL import Image, ImageFilter, ImageOps
# ----> 2 img = Image.open('e:/111.jpg')
#       3 def dodge(a, b, alpha):
#       4     return min(int(a*255/(256-b*alpha)), 255)
#       5 def draw(img, blur=25, alpha=1.0):
#
# d:\ProgramData\Anaconda3\lib\site-packages\PIL\Image.py in open(fp, mode)
#    2546
#    2547     if filename:
# -> 2548         fp = builtins.open(filename, "rb")
#    2549         exclusive_fp = True
#    2550
#
# FileNotFoundError: [Errno 2] No such file or directory: 'e:/111.jpg'
